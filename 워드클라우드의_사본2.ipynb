# %% [markdown]
# <a href="https://colab.research.google.com/github/yangyeji2020311166/ML/blob/main/%EC%9B%8C%EB%93%9C%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%EC%9D%98_%EC%82%AC%EB%B3%B82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update 
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev 
# !pip3 install JPype1-py3 
# !pip3 install konlpy 
# !JAVA_HOME="C:\Program Files\Java\jdk-17\"
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:3 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:4 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# ...

# %%
f=open('/content/라면 유튜브 크롤링 (16073).txt','r',encoding='utf-8')
txt = f.readlines()
f.close()

# %%
from konlpy.tag import Okt
from collections import Counter

twitter = Okt()
morphs = []

for sentence in txt:
    morphs.append(twitter.pos(sentence))
    
print(morphs)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
noun_list = []

for i in morphs:
    for word, tag in i:
        if tag in['Noun']:
            noun_list.append(word)

print(noun_list)

f = open("/content/stopwords_korean.txt", "rt", encoding="utf-8")
lines = f.readlines()
stopwords = []
for line in lines:
    line = line.replace('\n', '')
    stopwords.append(line)
f.close()

unique_Noun_words = set(noun_list)
for word in unique_Noun_words:
    if word in stopwords:
        while word in noun_list: noun_list.remove(word)
# Out:
# ['아이디', '댓글', '내용', '면', '남자', '봉', '여러분', '사', '개인', '맛', '맛', '라면', '퇴', '가우디', '더미', '장인', '라면', '라면', '특유', '인공', '스프', '맛', '안나', '가격', '가격', '조금', '인하', '의향', '가즈', '한번', '듯', '가격', '대비', '맛', '대가리', '도적', '가격', '가격', '누가', '저', '안', '돈', '맛', '그닥', '광일', '식당', '팔면', '하나', '가격', '라보', '가격', '걸처', '겟', '진라면', '신라면', '맛', '냐옹', '금액', '절반', '용서', '욕', '금', '빨', '풀', '철야', '정재형', '라면', '진짜', '선', '맛', '평가', '다른', '유투버', '비', '건더기', '퀄', '것', '한철', '장', '사용', '확', '라면', '라면', '자꾸', '전체', '가격', '상승', '효과', '최유진', '라면', '획기', '가격', '상승', '효과', '날', '수도', '벌써', '할인', '헬리오스', '전체', '면도', '국물', '누가', '완전', '다시', '산다', '파격', '행사', '사재기', '의향', '그르르', '매콤', '맛', '저', '그냥', '호불호', '태', '제', '입맛', '라면', '스프', '맛', '좀', '줄', '된장', '맛', '인스턴트', '느낌', '맛', '좀', '느낌', '다시', '선물', '찬장', '서랍', '한참', '한번', '법', '남', '추천', '정도', '쿠', '맛', '김밥', '다가', '헌터', '원래', '라면', '배', '약간', '라면', '가루', '형식', '이', '이건', '소스', '맛', '가격', '모델', '가요', '역시', '오징어', '게임', '밥', '진짜', '선', '영상', '보고', '면', '남자', '실제', 
# ...

# %%
count = Counter(noun_list)

words = (dict(count.most_common()))
print(words)
# Out:
# {'라면': 4246, '맛': 2765, '가격': 957, '리뷰': 783, '비건': 768, '사람': 764, '생각': 655, '신라면': 631, '컵라면': 567, '영상': 424, '면': 418, '불닭': 418, '봉지': 408, '비빔면': 395, '스프': 382, '정도': 380, '보고': 376, '볶음': 353, '제품': 323, '국물': 310, '왕뚜껑': 308, '느낌': 304, '한번': 301, '고기': 300, '오뚜기': 292, '돈': 291, '물': 256, '편의점': 250, '음식': 249, '진라면': 237, '상무': 225, '별로': 222, '개인': 217, '요즘': 217, '건더기': 216, '농심': 214, '김치': 213, '진': 207, '맵': 204, '국밥': 197, '회사': 194, '짬뽕': 185, '대만': 176, '광고': 175, '입맛': 162, '후추': 160, '이름': 160, '치즈': 158, '이유': 157, '배': 155, '우유': 154, '팔도': 153, '입': 153, '해': 152, '댓글': 151, '집': 148, '육개장': 145, '처음': 139, '밥': 138, '제이제이': 137, '뭔가': 135, '비교': 135, '나트륨': 134, '마트': 132, '사서': 131, '항상': 131, '소스': 129, '파': 129, '짜파게티': 129, '못': 127, '알': 127, '계란': 126, '자체': 124, '한국': 122, '짜장': 121, '도': 117, '아빠': 117, '열라면': 115, '치킨': 114, '예전': 113, '안성탕면': 113, '참깨': 113, '원래': 112, '소고기': 112, '민생': 112, '뚜껑': 112, '쿠폰': 112, '후기': 110, '열무': 110, '옛날': 109, '제
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

font = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'
wordcloud = WordCloud(font_path = font, background_color='white',colormap = "Accent_r", 
                      width=3000, height=2000).generate_from_frequencies(words) 

plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 156786 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
