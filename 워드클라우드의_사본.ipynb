# %% [markdown]
# <a href="https://colab.research.google.com/github/yangyeji2020311166/ML/blob/main/%EC%9B%8C%EB%93%9C%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update 
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev 
# !pip3 install JPype1-py3 
# !pip3 install konlpy 
# !JAVA_HOME="C:\Program Files\Java\jdk-17\"
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# ...

# %%
f=open('/content/스마트폰 유튜브 크롤링 (16709).txt','r',encoding='utf-8')
txt = f.readlines()
f.close()

# %%
from konlpy.tag import Okt
from collections import Counter

twitter = Okt()
morphs = []

for sentence in txt:
    morphs.append(twitter.pos(sentence))
    
print(morphs)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
noun_list = []

for i in morphs:
    for word, tag in i:
        if tag in['Noun']:
            noun_list.append(word)

print(noun_list)

f = open("/content/stopwords_korean.txt", "rt", encoding="utf-8")
lines = f.readlines()
stopwords = []
for line in lines:
    line = line.replace('\n', '')
    stopwords.append(line)
f.close()

unique_Noun_words = set(noun_list)
for word in unique_Noun_words:
    if word in stopwords:
        while word in noun_list: noun_list.remove(word)
# Out:
# ['아이디', '댓글', '내용', '이번', '폴', '방수', '외한', '면', '탭', '곳', '대화면', '이용', '더', '기능', '추가', '점', '가장', '마음', '드네', '저', '펜', '지원이', '마음', '원래', '노트', '유저', '아이폰', '요즘', '필기', '또', '태블릿', '생각', '차라리', '폴드', '를', '더', '뻔', '노트', '플러스', '울트라', '폴드', '구입', '로서', '펜', '때문', '폴드', '관심', '폴드', '눈', '이승', '필기', '태블릿', '무슨', '폴드', '에어', '필기', '만하', '소리', '닉네임', '이승', '사용자', '거', '왈가', '왈부', '듯', '노트', '시리즈', '팬층', '노트', '시리즈', '도', '펜', '활용', '유저', '층', '삼성', '스마트폰', '펜', '포기', '이유', '이승', '필기', '얘기', '그림', '그림', '걸', '진지', '빨', '능률', '이승', '닉네임', '필기', '용도', '급환', '일반', '이승', '네', '용도', '일반', '이정민', '디', '어빈', '이승', '말씀', '필기', '대학생', '공부', '필기', '에어', '거', '저', '메모', '부서장', '지시', '때', '타이핑', '훅훅', '때', '메모', '용', '펜', '주로', '편이', '검토', '때', '수정', '사항', '정도', '케', '스티', '전', '노트', '중고', '사서', '필기', '용', '보기', '태블릿', '폰', '글씨', '크게', '수', '나중', '때', '일일이', '확대', '그냥', '글씨', '크게', '효율', '오히려', '어디', '서나', '쓰기', '만약', '탭', '를', '노트북', '원래', '태블릿', '폰', '종', '세트', '건데', '부피', '무게', '로지', '사전예약', '사용
# ...

# %%
count = Counter(noun_list)

words = (dict(count.most_common()))
print(words)
# Out:
# {'아이폰': 2388, '폰': 1958, '플립': 1547, '갤럭시': 1306, '기능': 1102, '사용': 973, '영상': 967, '배터리': 901, '리뷰': 881, '폴드': 866, '삼성': 865, '화면': 752, '생각': 747, '카메라': 705, '미니': 692, '프로': 684, '디자인': 577, '사람': 515, '노트': 484, '애플': 469, '정도': 423, '성능': 398, '충전': 389, '시리즈': 381, '인트': 379, '보고': 377, '부분': 359, '가격': 356, '발열': 356, '게임': 339, '고민': 337, '설정': 335, '도': 333, '느낌': 332, '앱': 330, '주연': 310, '유튜브': 288, '단점': 287, '스마트폰': 282, '손': 281, '페이': 265, '핸드폰': 261, '이제': 258, '한번': 251, '문제': 246, '구매': 243, '케이스': 241, '인식': 238, '비교': 236, '디스플레이': 234, '울트라': 224, '소리': 224, '모델': 222, '액정': 221, '사진': 219, '점': 218, '버튼': 218, '제품': 216, '유저': 215, '차이': 215, '기본': 207, '무게': 202, '댓글': 200, '이유': 197, '다시': 197, '자체': 195, '처음': 194, '세대': 193, '돈': 189, '무선': 188, '가요': 185, '개인': 182, '별로': 180, '계속': 179, '지문': 178, '방수': 172, '항상': 171, '플래그': 168, '통화': 168, '만족': 165, '폴더': 165, '장점': 164, '확인': 163, '더블': 158, '펜': 157, '요즘': 157, '눈': 157, '필름': 157, '지원': 156, '개선':
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

font = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'
wordcloud = WordCloud(font_path = font, background_color='white',colormap = "Accent_r", 
                      width=3000, height=2000).generate_from_frequencies(words) 

plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 156786 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
